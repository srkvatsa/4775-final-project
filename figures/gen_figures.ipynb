# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
epochs = ["5", "10", "15", "20", "25", "200\n(early stopping\ntriggered at\nepoch 53/200)"]
accs = [0.8451, 0.8649, 0.8736, 0.8733, 0.8735, 0.8785]

plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Epochs (gap)")

plt.ylim([0.8, 0.9])

plt.bar(epochs, accs, width=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
epochs = ["5", "10", "15", "20", "25", "200\n(early stopping\ntriggered at\nepoch 33/200)"]
accs = [0.7300, 0.7368, 0.7398, 0.7405, 0.7420, 0.7442]

plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Epochs (nogap)")

plt.ylim([0.7, 0.8])

plt.bar(epochs, accs, width=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
epochs = ["Original\n(early stopping\ntriggered at\nepoch 53/200)", "DenseNet\n(early stopping\ntriggered at\nepoch 19/200)"]
accs = [0.8785, 0.8633]

plt.ylabel("Accuracy")
plt.title("Original Implementation vs DenseNet at 200 epochs (gap)")

plt.ylim([0.8, 0.9])

plt.bar(epochs, accs, width=0.5)
# Out:
# <BarContainer object of 2 artists>

# %%
epochs = ["Original\n(early stopping\ntriggered at\nepoch 33/200)", "DenseNet\n(early stopping\ntriggered at\nepoch 17/200)"]
accs = [0.7442, 0.7196]

plt.ylabel("Accuracy")
plt.title("Original Implementation vs DenseNet at 200 epochs (nogap)")

plt.ylim([0.6, 0.8])

plt.bar(epochs, accs, width=0.5)
# Out:
# <BarContainer object of 2 artists>
